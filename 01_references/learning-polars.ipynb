# %% [markdown]
# ---

# %% [markdown]
# #### **`polars` - "[...] is a blazingly fast DataFrame library for manipulating data."**

# %%
import polars as pl

# %% [markdown]
# ---

# %% [markdown]
# #### **a. The Basics, Loading a DataFrame**

# %%
# Creating a DataFrame from Scratch
df = pl.DataFrame(
    {
        "name": ["Ammar", "Federico", "Logan"],
        "surnames": ["Khan", "Castillo", "Tang"],
        "age": [22, 21, 21],

        "descriptions": [
            "Ammar is a fourth year student at UC Davis completing his degree in 'Agricultural and Environmental Technology'",
            "Federico is a third year student at UC Davis completing his degree in Economics",
            "Logan is a fourth year student at UC Davis completing his degree in Statistics"
        ]
    }
)
# Out:
# shape: (3, 4)
# ┌──────────┬──────────┬─────┬─────────────────────────────────┐
# │ name     ┆ surnames ┆ age ┆ descriptions                    │
# │ ---      ┆ ---      ┆ --- ┆ ---                             │
# │ str      ┆ str      ┆ i64 ┆ str                             │
# ╞══════════╪══════════╪═════╪═════════════════════════════════╡
# │ Ammar    ┆ Khan     ┆ 22  ┆ Ammar is a fourth year student… │
# │ Federico ┆ Castillo ┆ 21  ┆ Federico is a third year stude… │
# │ Logan    ┆ Tang     ┆ 21  ┆ Logan is a fourth year student… │
# └──────────┴──────────┴─────┴─────────────────────────────────┘

# %%
# Creating a DataFrame with a .csv File

# Creating .csv for Demonstration
import csv

# Loading with polars
df = pl.read_csv("demo.csv")
