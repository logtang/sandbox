# %% [markdown]
# ---

# %% [markdown]
# #### **Overview of Core Python Data Libraries**
# - **numpy** → numerical arrays, linear algebra foundation
# - **pandas** → tabular data manipulation
# - **matplotlib** → base plotting
# - **scipy** → scientific computing (stats, optimization)
# - **scikit-learn** → machine learning basics

# %% [markdown]
# ---

# %% [markdown]
# #### **`numpy`**

# %% [markdown]
# ---

# %% [markdown]
# #### **`pandas`**

# %% [markdown]
# ---

# %% [markdown]
# #### **`matplotlib`**

# %% [markdown]
# ---

# %% [markdown]
# #### **`scipy`**

# %% [markdown]
# ---

# %% [markdown]
# #### **`scikit-learn`**
