# %% [markdown]
# # **ANOVA Practice**

# %% [markdown]
# I'm recreating a guide for ANOVA that I made for myself in R. So the end here is to practice how all the data-handling stuff works in Python, and to focus a little less on the actual notation.
#
# But from the guide, say were testing for the differences between two types of fertilizer. And so we pose ourself questions like -
#
# "How many feet will some plant grow given fertilizers 1 or 2?"

# %%
import pandas as pd
import numpy as np 

# Loading the dataset
group1 = np.array([5.7, 4.2, 3.3, 4.7, 4.8, 5.2, 5.2, 4.3, 5.1, 6.3])
group2 = np.array([7.3, 7.3, 4.2, 9.6, 6.2, 9.3, 6.8, 7.0, 7.8, 10.2])
